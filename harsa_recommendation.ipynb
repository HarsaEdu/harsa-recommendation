# %%
# !pip install scikit-surprise
# !pip install pymysql
# !pip install python-dotenv
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163764 sha256=2b800dcc8075ccfd58f0b8c3ca723f881e88602f8a91032d3d14e1cbf64c774f
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3
# Collecting pymysql
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.0
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0

# %%
from dotenv import load_dotenv
import os
import pymysql
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import train_test_split
import pandas as pd

# %%
# Load environment variables from .env file
load_dotenv()

# Get MySQL connection details from environment variables
mysql_host = os.getenv("MYSQL_HOST")
mysql_user = os.getenv("MYSQL_USER")
mysql_password = os.getenv("MYSQL_PASSWORD")
mysql_database = os.getenv("MYSQL_DATABASE")

# %%
# Connect to MySQL
connection = pymysql.connect(
    host=mysql_host,
    user=mysql_user,
    password=mysql_password,
    database=mysql_database
)

# %%
courses = "SELECT * FROM courses WHERE deleted_at IS NULL"
courses = pd.read_sql(courses, connection)
pd.DataFrame(courses)
# Out:
# <ipython-input-49-0a14d3c8b379>:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   courses = pd.read_sql(courses, connection)
#    id  user_id                                              title  \
# 0   1        1                                                php
# 1   2        1  Menguasai Dunia Web: Panduan Komprehensif dala...
# 2   3        1  Membangun Dunia Interaktif: Panduan Komprehens...
# 3   4        1  Membangun Aplikasi Mobile: Panduan Komprehensi...
# 4   5        1  Mengukir Jejak di Dunia Mobile: Petunjuk Pinta...
#
#                                          description   rating  \
# 0  kelas ini mempelajari bagaimana cara penggunaa...  3.98886
# 1  Selamat datang di kelas "Menguasai Dunia Web"!...  3.96000
# 2  Selamat datang di kelas "Membangun Dunia Inter...  4.01600
# 3  Selamat datang di kelas "Membangun Aplikasi Mo...  4.19095
# 4  Selamat datang di kelas "Membangun Aplikasi Mo...  3.95624
#
#                               image_url              created_at  \
# 0  https://placewaifu.com/image/200/200 2023-12-04 06:27:16.977
# 1  https://placewaifu.com/image/200/200 2023-12-04 06:29:45.030
# 2  https://placewaifu.com/image/200/200 2023-12-04 06:36:30.713
# 3  https://placewaifu.com/image/200/200 2023-12-04 06:38:08.083
# 4  https://placewaifu.com/image/200/200 2023-12-04 06:38:54.950
#
#                updated_at deleted_at  category_id
# 0 2023-12-05 19:03:47.366       None            3
# 1 2023-12-05 19:05:36.991       None            3
# 2 2023-12-05 19:06:51.209       None            1
# 3 2023-12-05 19:07:15.803       None            2
# 4 2023-12-05 19:07:23.338       None            2

# %%
feedbacks = "SELECT * FROM feedbacks WHERE deleted_at IS NULL"
feedbacks = pd.read_sql(feedbacks, connection)
pd.DataFrame(feedbacks)
# Out:
# <ipython-input-65-1d0239302b1a>:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   feedbacks = pd.read_sql(feedbacks, connection)
#         id  user_id  course_id  rating  \
# 0        4        4          1       5
# 1        5        5          1       5
# 2        6        6          1       5
# 3        7        7          1       3
# 4        8        8          1       3
# ...    ...      ...        ...     ...
# 2769  2774      997          5       4
# 2770  2775      998          5       4
# 2771  2776      999          5       3
# 2772  2777     1000          5       5
# 2773  2783        2          1       4
#
#                                                 content  \
# 0     Cras mi pede, malesuada in, imperdiet et, comm...
# 1     Duis at velit eu est congue elementum. In hac ...
# 2     Phasellus id sapien in sapien iaculis congue. ...
# 3     Lorem ipsum dolor sit amet, consectetuer adipi...
# 4     Lorem ipsum dolor sit amet, consectetuer adipi...
# ...                                                 ...
# 2769  Nullam molestie nibh in lectus. Pellentesque a...
# 2770  Aliquam quis turpis eget elit sodales sceleris...
# 2771  Vivamus metus arcu, adipiscing molestie, hendr...
# 2772  Duis mattis egestas metus. Aenean fermentum. D...
# 2773                                               asik
#
#                   created_at              updated_at deleted_at
# 0    2022-12-24 19:47:21.000 2023-01-08 22:29:37.000       None
# 1    2023-04-13 08:47:47.000 2023-10-31 21:33:56.000       None
# 2    2023-04-04 19:24:03.000 2023-08-24 02:41:51.000       None
# 3    2023-03-18 06:14:35.000 2023-08-06 04:07:42.000       None
# 4    2023-10-15 21:15:56.000 2022-12-04 00:50:01.000       None
# ...                      ...                     ...        ...
# 2769 2023-09-11 15:15:17.000 2023-08-03 10:56:38.000       None
# 2770 2023-07-15 10:30:10.000 2023-05-24 18:38:49.000       None
# 2771 2023-07-28 19:08:56.000 2023-11-24 12:56:54.000       None
# 2772 2023-12-02 02:15:28.000 2022-12-17 18:48:21.000       None
# 2773 2023-12-05 19:03:47.105 2023-12-05 19:03:47.105       None
#
# [2774 rows x 8 columns]

# %%
user_interests = "SELECT * FROM user_interests"
user_interests = pd.read_sql(user_interests, connection)
pd.DataFrame(user_interests)
# Out:
# <ipython-input-38-b02c4f9f0559>:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   user_interests = pd.read_sql(user_interests, connection)
#    id  profile_id  category_id              created_at              updated_at
# 0   1           2            1 2023-12-04 08:02:25.825 2023-12-04 08:02:25.825
# 1   2           2            2 2023-12-04 08:02:25.892 2023-12-04 08:02:25.892

# %%
datas = """
SELECT feedbacks.id,
       feedbacks.user_id,
       feedbacks.course_id,
       feedbacks.rating,
       feedbacks.created_at AS feedback_created_at,
       courses.category_id,
       courses.created_at AS course_created_at
FROM feedbacks
JOIN courses
ON feedbacks.course_id = courses.id
WHERE feedbacks.deleted_at IS NULL;
"""

# Read the SQL query into a pandas DataFrame
datas = pd.read_sql(datas, connection)
pd.DataFrame(datas)
# Out:
# <ipython-input-74-d3b241bc9450>:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datas = pd.read_sql(datas, connection)
#         id  user_id  course_id  rating feedback_created_at  category_id  \
# 0        4        4          1       5 2022-12-24 19:47:21            3
# 1        5        5          1       5 2023-04-13 08:47:47            3
# 2        6        6          1       5 2023-04-04 19:24:03            3
# 3        7        7          1       3 2023-03-18 06:14:35            3
# 4        8        8          1       3 2023-10-15 21:15:56            3
# ...    ...      ...        ...     ...                 ...          ...
# 2769  2773      996          5       3 2023-02-03 11:54:47            2
# 2770  2774      997          5       4 2023-09-11 15:15:17            2
# 2771  2775      998          5       4 2023-07-15 10:30:10            2
# 2772  2776      999          5       3 2023-07-28 19:08:56            2
# 2773  2777     1000          5       5 2023-12-02 02:15:28            2
#
#            course_created_at
# 0    2023-12-04 06:27:16.977
# 1    2023-12-04 06:27:16.977
# 2    2023-12-04 06:27:16.977
# 3    2023-12-04 06:27:16.977
# 4    2023-12-04 06:27:16.977
# ...                      ...
# 2769 2023-12-04 06:38:54.950
# 2770 2023-12-04 06:38:54.950
# 2771 2023-12-04 06:38:54.950
# 2772 2023-12-04 06:38:54.950
# 2773 2023-12-04 06:38:54.950
#
# [2774 rows x 7 columns]

# %%
# Create a Reader object
reader = Reader(rating_scale=(1, 5))

# Load the data into a Surprise Dataset
data_surprise = Dataset.load_from_df(feedbacks[['user_id', 'course_id','rating']], reader)

# %%
# Use the KNNBasic collaborative filtering algorithm
sim_options = {'name': 'cosine', 'user_based': False}
recommendation_model = KNNBasic(sim_options=sim_options)

# Train the model on the entire dataset
trainset = data_surprise.build_full_trainset()
recommendation_model.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
def get_top_recommendations(model, user_id, data, user_interests, n=10):
    # Get user's interests (category_id)
    user_interest_categories = set(user_interests[user_interests['profile_id'] == user_id]['category_id'])

    # Get item predictions for the customer
    item_predictions = []
    user_rated_courses = set(data[data['user_id'] == user_id]['course_id'])

    for item_id in set(data['course_id']):
        # Skip courses the user has already rated
        if item_id in user_rated_courses:
            continue

        # Skip courses in the same category as user's interests
        course_category = data[data['course_id'] == item_id]['category_id'].values[0]
        if course_category in user_interest_categories:
            continue

        predicted_rating = model.predict(user_id, item_id).est
        item_predictions.append({'course_id': item_id, 'predicted_rating': predicted_rating})

    # Sort predictions by predicted rating
    item_predictions.sort(key=lambda x: x['predicted_rating'], reverse=True)

    # Get top recommended items
    top_recommendations = item_predictions[:n]

    return top_recommendations

# %%
get_top_recommendations(model=recommendation_model, user_id=3, data=datas, user_interests=user_interests, n=10)
# Out:
# [{'course_id': 1, 'predicted_rating': 5},
#  {'course_id': 2, 'predicted_rating': 3.994953136265321},
#  {'course_id': 3, 'predicted_rating': 3.994953136265321},
#  {'course_id': 5, 'predicted_rating': 3.994953136265321}]
